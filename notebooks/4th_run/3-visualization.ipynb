# %%
pacman::p_load(
    tidyverse, hrbrthemes, scales, paletteer, sf, basemaps, ggalluvial,
    ggrepel, xtable, stringdist, dendextend, ggpattern, tidytext, ggwordcloud,
    scales, viridis, cowplot, here, ggalluvial
)
source(here("src/visualization/visualization.R"))

# %%
round <- "4th_run"
dir_figure <- paste0(here("reports/figures/"), round, "/")
if (!dir.exists(dir_figure)) {
    dir.create(dir_figure)
}
path <- here()

# %%
# plot_wordclouds(path, round, dir_figure)
# plot_heatmap(path, round, dir_figure)
# plot_num_papers(paste0(path, "/data/external/scopus_input.csv"), dir_figure)
# plot_aspects(path, round, dir_figure)
# plot_study_area(path, round, dir_figure)
# plot_researcher_location(path, round, dir_figure)
# plot_study_area_researcher_location(
#     path, round, dir_figure
# )
# plot_study_area_researcher_location_alluvial(
#     path, round, dir_figure
# )
# plot_extent(path, round, dir_figure)
# plot_image_data_type(path, round, dir_figure)
# plot_subjective_data_type(path, round, dir_figure)
# plot_subjective_data_size(path, round, dir_figure)
# plot_type_of_research(path, round, dir_figure)
# plot_type_of_research_detail(path, round, dir_figure)
# plot_cv_model_purpose(path, round, dir_figure)
# plot_cv_model_training(path, round, dir_figure)
# plot_data_availability(path, round, dir_figure)
# plot_irb_approval(path, round, dir_figure)
plot_combined(path, round, dir_figure)
plot_image_data_type_by_study_area(path, round, dir_figure)
plot_image_data_type_by_extent(path, round, dir_figure)
plot_image_data_type_by_year(path, round, dir_figure)
plot_cv_model_purpose_by_year(path, round, dir_figure)
plot_cv_model_training_by_year(path, round, dir_figure)
plot_image_data_type_subjective_data_by_aspect(path, round, dir_figure)
# Out:
# Warning message in left_join(., citations, by = "X0"):
# "Detected an unexpected many-to-many relationship between `x` and `y`.
# i Row 26 of `x` matches multiple rows in `y`.
# i Row 52 of `y` matches multiple rows in `x`.
# i If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning."
# Warning message in left_join(., citations, by = c(filename = "X0")):
# "Detected an unexpected many-to-many relationship between `x` and `y`.
# i Row 245 of `x` matches multiple rows in `y`.
# i Row 95 of `y` matches multiple rows in `x`.
# i If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning."
# Warning message in left_join(., citations, by = c(filename = "X0")):
# "Detected an unexpected many-to-many relationship between `x` and `y`.
# i Row 246 of `x` matches multiple rows in `y`.
# i Row 130 of `y` matches multiple rows in `x`.
# ...
